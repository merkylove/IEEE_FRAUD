# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
import datetime
from IPython.display import clear_output
import lightgbm as lgb
from bayes_opt import BayesianOptimization
import matplotlib.pyplot as plt
import seaborn as sns
from catboost import CatBoostClassifier

from generate_features import generate_features_time_series
from read_utils import read_data
from settings import CATEGORICAL_FEATURES, COLUMNS_TO_REMOVE, USELESS_FEATURES_ACCORDING_TO_PERMUTATIONS
from sklearn.model_selection import GroupKFold

# %matplotlib inline


RANDOM_STATE = 42

# %%
# %%time
train, test, sample_submission = read_data()
train_test_transformed, encoders = generate_features_time_series(train, test)
# Out:
# Concatted 2019-09-16 12:28:48.850814
# /home/ec2-user/FRAUD/IEEE_FRAUD/feature_engineering.py:340: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   .apply(lambda x: len(np.unique(x))) \
# DT FEATURES 2019-09-16 12:41:10.955731
# /home/ec2-user/FRAUD/IEEE_FRAUD/feature_engineering.py:428: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lambda x: x if ' ' not in x else ' '.join(x.split()[:-1])
# /home/ec2-user/FRAUD/IEEE_FRAUD/feature_engineering.py:432: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
train_test_transformed.head()
# Out:
#                            TransactionID   C1  C10  C11  C12   C13  C14   C2  \
# TransactionDT_to_datetime
# 2017-12-01 00:00:00              2987000  1.0  0.0  2.0  0.0   1.0  1.0  1.0
# 2017-12-01 00:00:01              2987001  1.0  0.0  1.0  0.0   1.0  1.0  1.0
# 2017-12-01 00:01:09              2987002  1.0  0.0  1.0  0.0   1.0  1.0  1.0
# 2017-12-01 00:01:39              2987003  2.0  0.0  1.0  0.0  25.0  1.0  5.0
# 2017-12-01 00:01:46              2987004  1.0  1.0  1.0  0.0   1.0  1.0  1.0
#
#                             C3   C4  ...  \
# TransactionDT_to_datetime            ...
# 2017-12-01 00:00:00        0.0  0.0  ...
# 2017-12-01 00:00:01        0.0  0.0  ...
# 2017-12-01 00:01:09        0.0  0.0  ...
# 2017-12-01 00:01:39        0.0  0.0  ...
# 2017-12-01 00:01:46        0.0  0.0  ...
#
#                            smoothed_encoded_subcard_categorical_on_TransactionDT_hour_mean  \
# TransactionDT_to_datetime
# ...

# %%
from sklearn.model_selection import GroupKFold

folds = GroupKFold(n_splits=6)


preds = []

COLS_TO_USE = [
            i for i in train_test_transformed.columns
            if i not in COLUMNS_TO_REMOVE + ['__TMP'] + ['card1', 'subcard_categorical']# + ['card1', 'subcard_categorical', 'TransactionDT_dayOfMonth'] \
#    + USELESS_FEATURES_ACCORDING_TO_PERMUTATIONS \
#     + ['D1',
#             'D2',
#             'D3',
#             'D4',
#             'D5',
#             'D6',
#             'D7',
#             'D8',
#             'D10',
#             'D11',
#             'D12',
#             'D13',
#             'D14',
#             'D15',
#             'C1',
#             'C2',
#             'C4',
#             'C5',
#             'C6',
#             'C7',
#             'C8',
#             'C9',
#             'C10',
#             'C11',
#             'C12',
#             'C13',
#             'C14',
#             'subcard_reg_timestamp']
        ]

#COLS_TO_USE = ['C1', 'C10', 'C11', 'C12', 'C13', 'C14', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8', 'C9', 'D1', 'D10', 'D11', 'D12', 'D13', 'D14', 'D15', 'D2', 'D3', 'D4', 'D5', 'D6', 'D7', 'D8', 'D9', 'DeviceInfo', 'M3', 'M4', 'M5', 'M6', 'P_emaildomain', 'ProductCD', 'R_emaildomain', 'TransactionAmt', 'V102', 'V103', 'V128', 'V129', 'V131', 'V133', 'V152', 'V158', 'V165', 'V172', 'V187', 'V225', 'V245', 'V258', 'V281', 'V283', 'V308', 'V310', 'V312', 'V313', 'V315', 'V317', 'V34', 'V48', 'V49', 'V54', 'V62', 'V67', 'V69', 'V70', 'V77', 'V83', 'V87', 'V91', 'V98', 'addr1', 'card2', 'card5', 'id_01', 'id_02', 'id_06', 'id_13', 'id_19', 'id_20', 'id_30', 'id_33', 'subcard_reg_timestamp', 'time_from_prev_transaction_by_card1_subcard_categorical', 'time_to_next_transaction_by_card1_ProductCD_addr1', 'time_to_next_transaction_by_card1_subcard_categorical', 'card1_subcard_categorical_mean_time_between_transactions', 'card1_subcard_categorical_median_time_between_transactions', 'TransactionAmt_count_within_1min', 'TransactionAmt_sum_within_1min', 'TransactionAmt_mean_within_1min', 'TransactionAmt_sum_within_10min', 'TransactionAmt_mean_within_10min', 'cents', 'cents_categorical', 'P_emaildomain_1', 'P_emaildomain_2', 'R_emaildomain_1', 'card3_count', 'TransactionDT_hour_count', 'P_emaildomain_count', 'card1_addr1_count_how_typical', 'card2_addr1_count', 'card2_addr1_count_how_typical', 'card4_addr1_count_how_typical', 'card6_addr1_count', 'card1_P_emaildomain_count_how_typical', 'card1_R_emaildomain_count_how_typical', 'ProductCD_addr1_count_how_typical', 'ProductCD_count', 'card1_subcard_categorical_count', 'card1_subcard_categorical_ProductCD_count', 'card1_subcard_categorical_ProductCD_count_how_typical', 'card1_subcard_categorical_ProductCD_addr1_count', 'card1_subcard_categorical_ProductCD_addr1_count_how_typical', 'subcard_categorical_C1_count', 'subcard_categorical_C2_count', 'subcard_categorical_C5_count', 'subcard_categorical_C5_count_how_typical', 'subcard_categorical_C6_count', 'subcard_categorical_C6_count_how_typical', 'subcard_categorical_C9_count', 'subcard_categorical_C11_count', 'subcard_categorical_C11_count_how_typical', 'subcard_categorical_C13_count', 'subcard_categorical_C14_count', 'card1_C1_count', 'card1_C1_count_how_typical', 'card1_C2_count_how_typical', 'card1_C5_count_how_typical', 'card1_C6_count_how_typical', 'card1_C11_count', 'card1_C11_count_how_typical', 'card1_C12_count_how_typical', 'card1_C14_count', 'smoothed_encoded_card1_on_TransactionAmt_nanmedian', 'smoothed_encoded_card1_subcard_categorical_on_TransactionAmt_mean', 'smoothed_encoded_card1_subcard_categorical_on_TransactionAmt_std', 'smoothed_encoded_card1_subcard_categorical_on_TransactionAmt_nanmedian', 'smoothed_encoded_card1_on_dist1_std', 'smoothed_encoded_card1_on_dist1_nanmedian', 'smoothed_encoded_card1_subcard_categorical_on_dist1_mean', 'smoothed_encoded_card1_subcard_categorical_on_dist1_std', 'smoothed_encoded_card1_subcard_categorical_on_dist1_nanmedian', 'smoothed_encoded_card1_on_TransactionDT_hour_mean', 'smoothed_encoded_subcard_categorical_on_TransactionDT_hour_mean', 'smoothed_encoded_subcard_categorical_on_P_emaildomain_nunique', 'smoothed_encoded_card1_on_R_emaildomain_nunique', 'smoothed_encoded_subcard_categorical_on_R_emaildomain_nunique', 'smoothed_encoded_card1_TransactionDT_split_TransactionDT_dayOfMonth_TransactionDT_hour_on_TransactionAmt_sum']

print(COLS_TO_USE, len(COLS_TO_USE))


gbms = []

for fold_ind, (train_idx, val_idx) in enumerate(
    folds.split(
        X=train_test_transformed[:train.shape[0]], 
        y=train_test_transformed[:train.shape[0]]['isFraud'], 
        groups=train_test_transformed[:train.shape[0]]['TransactionDT_split'].tolist()
    )
):

    #if fold_ind == 0:
    #    continue

    print('Fold', fold_ind)

    pars = {
        'num_leaves': 2 ** 7 - 1,
        #'min_data_per_group': 100,
        'learning_rate': 0.01,
        'feature_fraction': 0.7,
        'bagging_fraction': 0.7,
        'bagging_seed': RANDOM_STATE,
        'bagging_freq': 51,
        'cat_smooth': 500,
        'lambda_l1': 1.0,
        'lambda_l2': 3.0,
        'max_bin': 100,
        'scale_pos_weight': 7.0,
        #'max_cat_to_onehot': 10,
        'boosting_type': 'gbdt',
        'objective': 'binary',
        'metric': ['auc'],
        'num_threads': -1,
        'seed': RANDOM_STATE
    }

    cat_c = [i for i in CATEGORICAL_FEATURES
        if i in COLS_TO_USE]

    cur_train = train_test_transformed[:train.shape[0]].iloc[train_idx].copy()
    cur_test = train_test_transformed[:train.shape[0]].iloc[val_idx].copy()

    cur_train = cur_train.sample(frac=1.0)
    
    #TARGET_ENCODE_COLUMN = 'cents_categorical'
    
    #cur_train = kfold_target_encoding(cur_train, [TARGET_ENCODE_COLUMN])
    #cur_test = apply_target_encoder(cur_train, cur_test, [TARGET_ENCODE_COLUMN])
    
    #cur_train[f'target_encoded_{TARGET_ENCODE_COLUMN}'] = cur_train[f'target_encoded_{TARGET_ENCODE_COLUMN}'].astype('float32')
    #cur_test[f'target_encoded_{TARGET_ENCODE_COLUMN}'] = cur_test[f'target_encoded_{TARGET_ENCODE_COLUMN}'].astype('float32')

    #cur_train_positive = cur_train[cur_train.isFraud == 1].copy()
    #cur_train_negative = cur_train[cur_train.isFraud == 0].sample(frac=0.2).copy()
    #cur_train = pd.concat([cur_train_positive, cur_train_negative])
    #cur_train = cur_train.sample(frac=.2)


    # create dataset for lightgbm
    lgb_train = lgb.Dataset(cur_train[COLS_TO_USE], cur_train['isFraud'])
    lgb_eval = lgb.Dataset(cur_test[COLS_TO_USE], cur_test['isFraud'], reference=lgb_train)

    gbm = lgb.train(
        pars,
        lgb_train,
        num_boost_round=20000,
        valid_sets=(lgb_train, lgb_eval),
        valid_names=('train', 'valid'),
        early_stopping_rounds=100,
        feature_name=COLS_TO_USE,
        categorical_feature=cat_c,
        verbose_eval=100
    )

    gbms.append(gbm)

    te = train_test_transformed[train_test_transformed['TransactionDT_split'] > 17].copy()
    #te = apply_target_encoder(pd.concat([cur_train, cur_test]), te, [TARGET_ENCODE_COLUMN])
    #te[f'target_encoded_{TARGET_ENCODE_COLUMN}'] = te[f'target_encoded_{TARGET_ENCODE_COLUMN}'].astype('float32')

    preds.append(gbm.predict(te[COLS_TO_USE]))


print(np.array(np.array([i.best_score['valid']['auc'] for i in gbms])).mean())
# Out:
# ['C1', 'C10', 'C11', 'C12', 'C13', 'C14', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8', 'C9', 'D1', 'D10', 'D11', 'D12', 'D13', 'D14', 'D15', 'D2', 'D3', 'D4', 'D5', 'D6', 'D7', 'D8', 'D9', 'DeviceInfo', 'DeviceType', 'M1', 'M2', 'M3', 'M4', 'M5', 'M6', 'M7', 'M8', 'M9', 'P_emaildomain', 'ProductCD', 'R_emaildomain', 'TransactionAmt', 'V1', 'V10', 'V100', 'V101', 'V102', 'V103', 'V104', 'V105', 'V106', 'V107', 'V108', 'V109', 'V11', 'V110', 'V111', 'V112', 'V113', 'V114', 'V115', 'V116', 'V117', 'V118', 'V119', 'V12', 'V120', 'V121', 'V122', 'V123', 'V124', 'V125', 'V126', 'V127', 'V128', 'V129', 'V13', 'V130', 'V131', 'V132', 'V133', 'V134', 'V135', 'V136', 'V137', 'V138', 'V139', 'V14', 'V140', 'V141', 'V142', 'V143', 'V144', 'V145', 'V146', 'V147', 'V148', 'V149', 'V15', 'V150', 'V151', 'V152', 'V153', 'V154', 'V155', 'V156', 'V157', 'V158', 'V159', 'V16', 'V160', 'V161', 'V162', 'V163', 'V164', 'V165', 'V166', 'V167', 'V168', 'V169', 'V17', 'V170', 'V171', 'V172', 'V173', 'V174', 'V1
# ...

# %%
['C1', 'C10', 'C11', 'C12', 'C13', 'C14', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8', 'C9', 'D1', 'D10', 'D11', 'D12', 'D13', 'D14', 'D15', 'D2', 'D3', 'D4', 'D5', 'D6', 'D7', 'D8', 'D9', 'DeviceInfo', 'DeviceType', 'M1', 'M2', 'M3', 'M4', 'M5', 'M6', 'M7', 'M8', 'M9', 'P_emaildomain', 'ProductCD', 'R_emaildomain', 'TransactionAmt', 'V1', 'V10', 'V100', 'V101', 'V102', 'V103', 'V104', 'V105', 'V106', 'V107', 'V108', 'V109', 'V11', 'V110', 'V111', 'V112', 'V113', 'V114', 'V115', 'V116', 'V117', 'V118', 'V119', 'V12', 'V120', 'V121', 'V122', 'V123', 'V124', 'V125', 'V126', 'V127', 'V128', 'V129', 'V13', 'V130', 'V131', 'V132', 'V133', 'V134', 'V135', 'V136', 'V137', 'V138', 'V139', 'V14', 'V140', 'V141', 'V142', 'V143', 'V144', 'V145', 'V146', 'V147', 'V148', 'V149', 'V15', 'V150', 'V151', 'V152', 'V153', 'V154', 'V155', 'V156', 'V157', 'V158', 'V159', 'V16', 'V160', 'V161', 'V162', 'V163', 'V164', 'V165', 'V166', 'V167', 'V168', 'V169', 'V17', 'V170', 'V171', 'V172', 'V173', 'V174', 'V175', 'V176', 'V177', 'V178', 'V179', 'V18', 'V180', 'V181', 'V182', 'V183', 'V184', 'V185', 'V186', 'V187', 'V188', 'V189', 'V19', 'V190', 'V191', 'V192', 'V193', 'V194', 'V195', 'V196', 'V197', 'V198', 'V199', 'V2', 'V20', 'V200', 'V201', 'V202', 'V203', 'V204', 'V205', 'V206', 'V207', 'V208', 'V209', 'V21', 'V210', 'V211', 'V212', 'V213', 'V214', 'V215', 'V216', 'V217', 'V218', 'V219', 'V22', 'V220', 'V221', 'V222', 'V223', 'V224', 'V225', 'V226', 'V227', 'V228', 'V229', 'V23', 'V230', 'V231', 'V232', 'V233', 'V234', 'V235', 'V236', 'V237', 'V238', 'V239', 'V24', 'V240', 'V241', 'V242', 'V243', 'V244', 'V245', 'V246', 'V247', 'V248', 'V249', 'V25', 'V250', 'V251', 'V252', 'V253', 'V254', 'V255', 'V256', 'V257', 'V258', 'V259', 'V26', 'V260', 'V261', 'V262', 'V263', 'V264', 'V265', 'V266', 'V267', 'V268', 'V269', 'V27', 'V270', 'V271', 'V272', 'V273', 'V274', 'V275', 'V276', 'V277', 'V278', 'V279', 'V28', 'V280', 'V281', 'V282', 'V283', 'V284', 'V285', 'V286', 'V287', 'V288', 'V289', 'V29', 'V290', 'V291', 'V292', 'V293', 'V294', 'V295', 'V296', 'V297', 'V298', 'V299', 'V3', 'V30', 'V300', 'V301', 'V302', 'V303', 'V304', 'V305', 'V306', 'V307', 'V308', 'V309', 'V31', 'V310', 'V311', 'V312', 'V313', 'V314', 'V315', 'V316', 'V317', 'V318', 'V319', 'V32', 'V320', 'V321', 'V322', 'V323', 'V324', 'V325', 'V326', 'V327', 'V328', 'V329', 'V33', 'V330', 'V331', 'V332', 'V333', 'V334', 'V335', 'V336', 'V337', 'V338', 'V339', 'V34', 'V35', 'V36', 'V37', 'V38', 'V39', 'V4', 'V40', 'V41', 'V42', 'V43', 'V44', 'V45', 'V46', 'V47', 'V48', 'V49', 'V5', 'V50', 'V51', 'V52', 'V53', 'V54', 'V55', 'V56', 'V57', 'V58', 'V59', 'V6', 'V60', 'V61', 'V62', 'V63', 'V64', 'V65', 'V66', 'V67', 'V68', 'V69', 'V7', 'V70', 'V71', 'V72', 'V73', 'V74', 'V75', 'V76', 'V77', 'V78', 'V79', 'V8', 'V80', 'V81', 'V82', 'V83', 'V84', 'V85', 'V86', 'V87', 'V88', 'V89', 'V9', 'V90', 'V91', 'V92', 'V93', 'V94', 'V95', 'V96', 'V97', 'V98', 'V99', 'addr1', 'addr2', 'card2', 'card3', 'card4', 'card5', 'card6', 'dist1', 'dist2', 'id_01', 'id_02', 'id_03', 'id_04', 'id_05', 'id_06', 'id_07', 'id_08', 'id_09', 'id_10', 'id_11', 'id_12', 'id_13', 'id_14', 'id_15', 'id_16', 'id_17', 'id_18', 'id_19', 'id_20', 'id_21', 'id_22', 'id_23', 'id_24', 'id_25', 'id_26', 'id_27', 'id_28', 'id_29', 'id_30', 'id_31', 'id_32', 'id_33', 'id_34', 'id_35', 'id_36', 'id_37', 'id_38', 'subcard_reg_timestamp', 'time_from_prev_transaction_by_card1', 'time_from_prev_transaction_by_card1_ProductCD', 'time_from_prev_transaction_by_card1_ProductCD_addr1', 'time_from_prev_transaction_by_card1_subcard_categorical', 'time_to_next_transaction_by_card1', 'time_to_next_transaction_by_card1_ProductCD', 'time_to_next_transaction_by_card1_ProductCD_addr1', 'time_to_next_transaction_by_card1_subcard_categorical', 'TransactionDT_weekOfMonth', 'TransactionDT_hour', 'is_holiday', 'card1_subcard_categorical_mean_time_between_transactions', 'card1_subcard_categorical_median_time_between_transactions', 'time_from_prev_transaction_by_card1_subcard_categorical_ratio_to_mean', 'time_from_prev_transaction_by_card1_subcard_categorical_ratio_to_median', 'time_to_next_transaction_by_card1_subcard_categorical_ratio_to_mean', 'time_to_next_transaction_by_card1_subcard_categorical_ratio_to_median', 'TransactionAmt_count_within_1min', 'TransactionAmt_sum_within_1min', 'TransactionAmt_mean_within_1min', 'TransactionAmt_std_within_1min', 'TransactionAmt_unique_within_1min', 'TransactionAmt_count_within_10min', 'TransactionAmt_sum_within_10min', 'TransactionAmt_mean_within_10min', 'TransactionAmt_std_within_10min', 'TransactionAmt_unique_within_10min', 'Transaction_Number', 'Transaction_Number_normed', 'cents', 'cents_categorical', 'OS_NAME', 'OS_V0', 'OS_V1', 'OS_V2', 'OS_V_COMBINED', 'OS_V_MAJOR', 'OS_VERSION_FULL', 'OS_VERSION_MINIMAL', 'P_emaildomain_1', 'P_emaildomain_2', 'P_emaildomain_3', 'R_emaildomain_1', 'R_emaildomain_2', 'R_emaildomain_3', 'device_name', 'prev_1_card1_ProductCD_TransactionAmt', 'next_1_card1_ProductCD_TransactionAmt', 'card3_count', 'TransactionDT_hour_count', 'R_emaildomain_count', 'P_emaildomain_count', 'card2_addr1_count', 'card2_addr1_count_how_typical', 'card1_TransactionDT_hour_count', 'card1_TransactionDT_hour_count_how_typical', 'ProductCD_count', 'card1_subcard_categorical_ProductCD_count', 'card1_subcard_categorical_ProductCD_count_how_typical', 'card1_subcard_categorical_ProductCD_addr1_count', 'card1_subcard_categorical_ProductCD_addr1_count_how_typical', 'card1_addr1_count', 'card1_addr1_count_how_typical', 'ProductCD_addr1_count', 'ProductCD_addr1_count_how_typical', 'subcard_categorical_R_emaildomain_count', 'subcard_categorical_R_emaildomain_count_how_typical', 'subcard_categorical_P_emaildomain_count', 'subcard_categorical_P_emaildomain_count_how_typical', 'card1_subcard_categorical_count', 'card1_subcard_categorical_count_how_typical', 'card1_count', 'card2_count', 'card4_count', 'card5_count', 'card6_count', 'addr1_count', 'addr2_count', 'TransactionDT_dayOfMonth_count', 'TransactionDT_weekOfMonth_count', 'DeviceInfo_count', 'device_name_count', 'card3_addr1_count', 'card3_addr1_count_how_typical', 'card4_addr1_count', 'card4_addr1_count_how_typical', 'card6_addr1_count', 'card6_addr1_count_how_typical', 'card1_P_emaildomain_count', 'card1_P_emaildomain_count_how_typical', 'card1_R_emaildomain_count', 'card1_R_emaildomain_count_how_typical', 'card1_ProductCD_count', 'card1_ProductCD_count_how_typical', 'card1_ProductCD_addr1_count', 'card1_ProductCD_addr1_count_how_typical', 'subcard_categorical_C1_count', 'subcard_categorical_C1_count_how_typical', 'subcard_categorical_C2_count', 'subcard_categorical_C2_count_how_typical', 'subcard_categorical_C3_count', 'subcard_categorical_C3_count_how_typical', 'subcard_categorical_C4_count', 'subcard_categorical_C4_count_how_typical', 'subcard_categorical_C5_count', 'subcard_categorical_C5_count_how_typical', 'subcard_categorical_C6_count', 'subcard_categorical_C6_count_how_typical', 'subcard_categorical_C7_count', 'subcard_categorical_C7_count_how_typical', 'subcard_categorical_C8_count', 'subcard_categorical_C8_count_how_typical', 'subcard_categorical_C9_count', 'subcard_categorical_C9_count_how_typical', 'subcard_categorical_C10_count', 'subcard_categorical_C10_count_how_typical', 'subcard_categorical_C11_count', 'subcard_categorical_C11_count_how_typical', 'subcard_categorical_C12_count', 'subcard_categorical_C12_count_how_typical', 'subcard_categorical_C13_count', 'subcard_categorical_C13_count_how_typical', 'subcard_categorical_C14_count', 'subcard_categorical_C14_count_how_typical', 'card1_C1_count', 'card1_C1_count_how_typical', 'card1_C2_count', 'card1_C2_count_how_typical', 'card1_C3_count', 'card1_C3_count_how_typical', 'card1_C4_count', 'card1_C4_count_how_typical', 'card1_C5_count', 'card1_C5_count_how_typical', 'card1_C6_count', 'card1_C6_count_how_typical', 'card1_C7_count', 'card1_C7_count_how_typical', 'card1_C8_count', 'card1_C8_count_how_typical', 'card1_C9_count', 'card1_C9_count_how_typical', 'card1_C10_count', 'card1_C10_count_how_typical', 'card1_C11_count', 'card1_C11_count_how_typical', 'card1_C12_count', 'card1_C12_count_how_typical', 'card1_C13_count', 'card1_C13_count_how_typical', 'card1_C14_count', 'card1_C14_count_how_typical', 'card1_subcard_categorical_TransactionDT_split_TransactionDT_dayOfMonth_count', 'card1_subcard_categorical_TransactionDT_split_TransactionDT_dayOfMonth_TransactionDT_hour_count', 'smoothed_encoded_card1_on_TransactionAmt_mean', 'smoothed_encoded_card1_on_TransactionAmt_std', 'smoothed_encoded_card1_on_TransactionAmt_nanmedian', 'smoothed_encoded_card2_on_TransactionAmt_mean', 'smoothed_encoded_card2_on_TransactionAmt_std', 'smoothed_encoded_card2_on_TransactionAmt_nanmedian', 'smoothed_encoded_card3_on_TransactionAmt_mean', 'smoothed_encoded_card3_on_TransactionAmt_std', 'smoothed_encoded_card3_on_TransactionAmt_nanmedian', 'smoothed_encoded_card5_on_TransactionAmt_mean', 'smoothed_encoded_card5_on_TransactionAmt_std', 'smoothed_encoded_card5_on_TransactionAmt_nanmedian', 'smoothed_encoded_TransactionDT_hour_on_TransactionAmt_mean', 'smoothed_encoded_TransactionDT_hour_on_TransactionAmt_std', 'smoothed_encoded_TransactionDT_hour_on_TransactionAmt_nanmedian', 'smoothed_encoded_TransactionDT_dayOfMonth_on_TransactionAmt_mean', 'smoothed_encoded_TransactionDT_dayOfMonth_on_TransactionAmt_std', 'smoothed_encoded_TransactionDT_dayOfMonth_on_TransactionAmt_nanmedian', 'smoothed_encoded_TransactionDT_weekOfMonth_on_TransactionAmt_mean', 'smoothed_encoded_TransactionDT_weekOfMonth_on_TransactionAmt_std', 'smoothed_encoded_TransactionDT_weekOfMonth_on_TransactionAmt_nanmedian', 'smoothed_encoded_card1_subcard_categorical_on_TransactionAmt_mean', 'smoothed_encoded_card1_subcard_categorical_on_TransactionAmt_std', 'smoothed_encoded_card1_subcard_categorical_on_TransactionAmt_nanmedian', 'smoothed_encoded_card1_on_dist1_std', 'smoothed_encoded_card1_on_dist1_nanmedian', 'smoothed_encoded_card1_subcard_categorical_on_dist1_mean', 'smoothed_encoded_card1_subcard_categorical_on_dist1_std', 'smoothed_encoded_card1_subcard_categorical_on_dist1_nanmedian', 'smoothed_encoded_card1_on_TransactionDT_hour_mean', 'smoothed_encoded_subcard_categorical_on_TransactionDT_hour_mean', 'smoothed_encoded_subcard_categorical_on_P_emaildomain_nunique', 'smoothed_encoded_subcard_categorical_on_R_emaildomain_nunique', 'smoothed_encoded_card1_on_R_emaildomain_nunique', 'smoothed_encoded_card2_on_card1_nunique', 'smoothed_encoded_card4_on_card1_nunique', 'smoothed_encoded_card6_on_card1_nunique', 'smoothed_encoded_card2_card3_on_card1_nunique', 'smoothed_encoded_addr1_on_card1_nunique', 'smoothed_encoded_card1_TransactionDT_split_TransactionDT_dayOfMonth_TransactionDT_hour_on_TransactionAmt_sum', 'D1_normed_by_TransactionDT_split_TransactionDT_dayOfMonth', 'D2_normed_by_TransactionDT_split_TransactionDT_dayOfMonth', 'D3_normed_by_TransactionDT_split_TransactionDT_dayOfMonth', 'D4_normed_by_TransactionDT_split_TransactionDT_dayOfMonth', 'D5_normed_by_TransactionDT_split_TransactionDT_dayOfMonth', 'D6_normed_by_TransactionDT_split_TransactionDT_dayOfMonth', 'D7_normed_by_TransactionDT_split_TransactionDT_dayOfMonth', 'D8_normed_by_TransactionDT_split_TransactionDT_dayOfMonth', 'D10_normed_by_TransactionDT_split_TransactionDT_dayOfMonth', 'D11_normed_by_TransactionDT_split_TransactionDT_dayOfMonth', 'D12_normed_by_TransactionDT_split_TransactionDT_dayOfMonth', 'D13_normed_by_TransactionDT_split_TransactionDT_dayOfMonth', 'D14_normed_by_TransactionDT_split_TransactionDT_dayOfMonth', 'D15_normed_by_TransactionDT_split_TransactionDT_dayOfMonth', 'C1_normed_by_TransactionDT_split_TransactionDT_dayOfMonth', 'C2_normed_by_TransactionDT_split_TransactionDT_dayOfMonth', 'C4_normed_by_TransactionDT_split_TransactionDT_dayOfMonth', 'C5_normed_by_TransactionDT_split_TransactionDT_dayOfMonth', 'C6_normed_by_TransactionDT_split_TransactionDT_dayOfMonth', 'C7_normed_by_TransactionDT_split_TransactionDT_dayOfMonth', 'C8_normed_by_TransactionDT_split_TransactionDT_dayOfMonth', 'C9_normed_by_TransactionDT_split_TransactionDT_dayOfMonth', 'C10_normed_by_TransactionDT_split_TransactionDT_dayOfMonth', 'C11_normed_by_TransactionDT_split_TransactionDT_dayOfMonth', 'C12_normed_by_TransactionDT_split_TransactionDT_dayOfMonth', 'C13_normed_by_TransactionDT_split_TransactionDT_dayOfMonth', 'C14_normed_by_TransactionDT_split_TransactionDT_dayOfMonth', 'subcard_reg_timestamp_normed_by_TransactionDT_split_TransactionDT_dayOfMonth', 'D1_normed_by_TransactionDT_split_TransactionDT_dayOfMonth_card1', 'D2_normed_by_TransactionDT_split_TransactionDT_dayOfMonth_card1', 'D3_normed_by_TransactionDT_split_TransactionDT_dayOfMonth_card1', 'D4_normed_by_TransactionDT_split_TransactionDT_dayOfMonth_card1', 'D5_normed_by_TransactionDT_split_TransactionDT_dayOfMonth_card1', 'D6_normed_by_TransactionDT_split_TransactionDT_dayOfMonth_card1', 'D7_normed_by_TransactionDT_split_TransactionDT_dayOfMonth_card1', 'D8_normed_by_TransactionDT_split_TransactionDT_dayOfMonth_card1', 'D10_normed_by_TransactionDT_split_TransactionDT_dayOfMonth_card1', 'D11_normed_by_TransactionDT_split_TransactionDT_dayOfMonth_card1', 'D12_normed_by_TransactionDT_split_TransactionDT_dayOfMonth_card1', 'D13_normed_by_TransactionDT_split_TransactionDT_dayOfMonth_card1', 'D14_normed_by_TransactionDT_split_TransactionDT_dayOfMonth_card1', 'D15_normed_by_TransactionDT_split_TransactionDT_dayOfMonth_card1', 'C1_normed_by_TransactionDT_split_TransactionDT_dayOfMonth_card1', 'C2_normed_by_TransactionDT_split_TransactionDT_dayOfMonth_card1', 'C4_normed_by_TransactionDT_split_TransactionDT_dayOfMonth_card1', 'C5_normed_by_TransactionDT_split_TransactionDT_dayOfMonth_card1', 'C6_normed_by_TransactionDT_split_TransactionDT_dayOfMonth_card1', 'C7_normed_by_TransactionDT_split_TransactionDT_dayOfMonth_card1', 'C8_normed_by_TransactionDT_split_TransactionDT_dayOfMonth_card1', 'C9_normed_by_TransactionDT_split_TransactionDT_dayOfMonth_card1', 'C10_normed_by_TransactionDT_split_TransactionDT_dayOfMonth_card1', 'C11_normed_by_TransactionDT_split_TransactionDT_dayOfMonth_card1', 'C12_normed_by_TransactionDT_split_TransactionDT_dayOfMonth_card1', 'C13_normed_by_TransactionDT_split_TransactionDT_dayOfMonth_card1', 'C14_normed_by_TransactionDT_split_TransactionDT_dayOfMonth_card1', 'subcard_reg_timestamp_normed_by_TransactionDT_split_TransactionDT_dayOfMonth_card1'] 681
Fold 0
/home/ec2-user/miniconda3/envs/FRAUD/lib/python3.7/site-packages/lightgbm/basic.py:1209: UserWarning: categorical_feature in Dataset is overridden.
New categorical_feature is ['DeviceInfo', 'DeviceType', 'M1', 'M2', 'M3', 'M4', 'M5', 'M6', 'M7', 'M8', 'M9', 'OS_NAME', 'OS_V0', 'OS_V1', 'OS_V2', 'OS_VERSION_FULL', 'OS_VERSION_MINIMAL', 'OS_V_MAJOR', 'P_emaildomain', 'P_emaildomain_1', 'P_emaildomain_2', 'P_emaildomain_3', 'ProductCD', 'R_emaildomain', 'R_emaildomain_1', 'R_emaildomain_2', 'R_emaildomain_3', 'addr1', 'addr2', 'card2', 'card3', 'card4', 'card5', 'card6', 'cents_categorical', 'device_name', 'id_12', 'id_13', 'id_14', 'id_15', 'id_16', 'id_17', 'id_18', 'id_19', 'id_20', 'id_21', 'id_22', 'id_23', 'id_24', 'id_25', 'id_26', 'id_27', 'id_28', 'id_29', 'id_30', 'id_31', 'id_32', 'id_33', 'id_34', 'id_35', 'id_36', 'id_37', 'id_38', 
[1500]	train's auc: 0.998926	valid's auc: 0.96232
[1600]	train's auc: 0.999131	valid's auc: 0.962608
[1700]	train's auc: 0.999292	valid's auc: 0.962613
Early stopping, best iteration is:
[1613]	train's auc: 0.999153	valid's auc: 0.962642
0.9512888067623475
# Out:
# {'M7_isnull',
#  'TransactionAmt_count_within_1min',
#  'V133_diff1',
#  'card1_P_emaildomain_count_how_typical',
#  'card1_R_emaildomain_count_how_typical',
#  'card4_addr1_count_how_typical',
#  'card6_addr1_count'}

# %%
sample_submission['TransactionID'] = train_test_transformed[train.shape[0]:]['TransactionID'].values
sample_submission['isFraud'] = np.array(preds).mean(axis=0)
sample_submission.head()

vv = np.array([i.best_score['valid']['auc'] for i in gbms]).mean()
filename = f'submit_ts_kfold_{vv}_mean_shuffled.csv'
sample_submission.to_csv(filename, index=None)
print(filename)

# !KAGGLE_USERNAME=merkylove KAGGLE_KEY=d5a91994e09f1cb75e62c8b8b2967594 kaggle competitions submit ieee-fraud-detection -f {filename} -m "auto"
# Out:
# submit_ts_kfold_0.9514214342894851_mean_shuffled.csv
# 100%|██████████████████████████████████████| 13.9M/13.9M [00:00<00:00, 14.9MB/s]
# Successfully submitted to IEEE-CIS Fraud Detection

# %%
r = gbms[1].predict(
    train_test_transformed[
        (train_test_transformed['TransactionDT_split'] >= 19)
    ].sample(10000)[COLS_TO_USE],
    pred_contrib=True
)

mean_shap = np.abs(r).mean(axis=0)


shap_imp = pd.DataFrame(sorted(zip(mean_shap, COLS_TO_USE)), columns=['Value','Feature'])
plt.figure(figsize=(10, 20))
sns.barplot(x="Value", y="Feature", data=shap_imp.sort_values(by="Value", ascending=False)[:150])
plt.tight_layout()
plt.show()

# %%
MEANINGFUL_COLUMNS = shap_imp[shap_imp.Value > 0.00001]['Feature'].tolist()

# %%
shap_imp['Feature'].tolist()
# Out:
# ['TransactionAmt_count_within_1min',
#  'V107',
#  'V112',
#  'V117',
#  'V118',
#  'V119',
#  'V120',
#  'V122',
#  'V14',
#  'V236',
#  'V240',
#  'V241',
#  'V269',
#  'V27',
#  'V28',
#  'V297',
#  'V305',
#  'V325',
#  'V41',
#  'V65',
#  'V68',
#  'V88',
#  'V89',
#  'id_21',
#  'id_22',
#  'id_24',
#  'id_26',
#  'id_27',
#  'V111',
#  'V16',
#  'V114',
#  'V21',
#  'V330',
#  'V247',
#  'V302',
#  'V153',
#  'V95',
#  'addr2_count',
#  'V1',
#  'V142',
#  'id_35',
#  'V106',
#  'V103',
#  'M1',
#  'V121',
#  'V113',
#  'V116',
#  'addr2',
#  'V226',
#  'V298',
#  'R_emaildomain_3',
#  'V299',
#  'V97',
#  'V167',
#  'V193',
#  'V9',
#  'V196',
#  'TransactionAmt_unique_within_1min',
#  'V288',
#  'V105',
#  'V191',
#  'V284',
#  'id_25',
#  'V104',
#  'V101',
#  'V235',
#  'V110',
#  'V141',
#  'V100',
#  'V195',
#  'V329',
#  'V242',
#  'id_10',
#  'V186',
#  'V80',
#  'V252',
#  'V237',
#  'V197',
#  'V98',
#  'OS_V0',
#  'V17',
#  'V238',
#  'V303',
#  'V174',
#  'V179',
# ...
