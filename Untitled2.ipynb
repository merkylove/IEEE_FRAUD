# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
import datetime
from IPython.display import clear_output
import lightgbm as lgb
from bayes_opt import BayesianOptimization
import matplotlib.pyplot as plt
import seaborn as sns
from catboost import CatBoostClassifier

from generate_features import generate_features_time_series
from read_utils import read_data
from settings import CATEGORICAL_FEATURES, COLUMNS_TO_REMOVE, USELESS_FEATURES_ACCORDING_TO_PERMUTATIONS
from sklearn.model_selection import GroupKFold

# %matplotlib inline


RANDOM_STATE = 42

# %%
# %%time
train, test, sample_submission = read_data()
train_test_transformed, encoders = generate_features_time_series(train, test)
# Out:
# NEW
# Starting 2019-09-16 19:25:46.200433
# Concatted 2019-09-16 19:31:30.337364
# /home/ec2-user/FRAUD/IEEE_FRAUD/feature_engineering.py:346: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   .apply(lambda x: len(np.unique(x))) \
# DT FEATURES 2019-09-16 19:44:33.234743
# /home/ec2-user/FRAUD/IEEE_FRAUD/feature_engineering.py:434: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lambda x: x if ' ' not in x else ' '.join(x.split()[:-1])
# /home/ec2-user/FRAUD/IEEE_FRAUD/feature_engineering.py:438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lambda x: parse_version(x.split()[-1])[0]
# /home/ec2-user/FRAUD/IEEE_FRAUD/feature_engineering.py:442: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lambda x: parse_version(x.split()[-1])[1]
# /home/ec2-user/FRAUD/IEEE_FRAUD/feature_engineering.py:446: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lambda x: parse_version(x.split()[-1])[2]
# ids, emaildomain 2019-09-16 19:45:11.754276
# Count features 2019-09-16 19:47:24.884727
# target encoding 2019-09-16 19:47:24.884918
# Mean Encoding 2019-09-16 19:53:34.027788
# Encoders 2019-09-16 19:55:04.555487
# CPU times: user 43min 41s, sys: 17min 29s, total: 1h 1min 10s
# Wall time: 29min 58s

# %%
train_test_transformed.head()
# Out:
#                            TransactionID   C1  C10  C11  C12   C13  C14   C2  \
# TransactionDT_to_datetime
# 2017-12-01 00:00:00              2987000  1.0  0.0  2.0  0.0   1.0  1.0  1.0
# 2017-12-01 00:00:01              2987001  1.0  0.0  1.0  0.0   1.0  1.0  1.0
# 2017-12-01 00:01:09              2987002  1.0  0.0  1.0  0.0   1.0  1.0  1.0
# 2017-12-01 00:01:39              2987003  2.0  0.0  1.0  0.0  25.0  1.0  5.0
# 2017-12-01 00:01:46              2987004  1.0  1.0  1.0  0.0   1.0  1.0  1.0
#
#                             C3   C4  ...  \
# TransactionDT_to_datetime            ...
# 2017-12-01 00:00:00        0.0  0.0  ...
# 2017-12-01 00:00:01        0.0  0.0  ...
# 2017-12-01 00:01:09        0.0  0.0  ...
# 2017-12-01 00:01:39        0.0  0.0  ...
# 2017-12-01 00:01:46        0.0  0.0  ...
#
#                            smoothed_encoded_card4_on_card1_nunique  \
# TransactionDT_to_datetime
# 2017-12-01 00:00:00                                           21.0
# 2017-12-01 00:00:01                                         5750.0
# 2017-12-01 00:01:09                                         9705.0
# 2017-12-01 00:01:39                                         5750.0
# 2017-12-01 00:01:46                                         5750.0
#
#                            smoothed_encoded_card6_on_card1_nunique  \
# TransactionDT_to_datetime
# 2017-12-01 00:00:00                                         7214.0
# 2017-12-01 00:00:01                                         7214.0
# 2017-12-01 00:01:09                                         9994.0
# 2017-12-01 00:01:39                                         9994.0
# 2017-12-01 00:01:46                                         7214.0
#
#                            smoothed_encoded_card2_card3_on_card1_nunique  \
# TransactionDT_to_datetime
# 2017-12-01 00:00:00                                                  NaN
# 2017-12-01 00:00:01                                                 19.0
# 2017-12-01 00:01:09                                                125.0
# 2017-12-01 00:01:39                                                 34.0
# 2017-12-01 00:01:46                                                116.0
#
#                            smoothed_encoded_addr1_on_card1_nunique  \
# TransactionDT_to_datetime
# 2017-12-01 00:00:00                                         1750.0
# 2017-12-01 00:00:01                                         2205.0
# 2017-12-01 00:01:09                                         1886.0
# 2017-12-01 00:01:39                                         1018.0
# 2017-12-01 00:01:46                                          642.0
#
#                            smoothed_encoded_card1_TransactionDT_split_TransactionDT_dayOfMonth_TransactionDT_hour_on_TransactionAmt_sum  \
# TransactionDT_to_datetime
# 2017-12-01 00:00:00                                                    68.50
# 2017-12-01 00:00:01                                                    29.00
# 2017-12-01 00:01:09                                                   106.95
# 2017-12-01 00:01:39                                                   286.95
# 2017-12-01 00:01:46                                                    50.00
#
#                            D8_not_same_day  D8_D9_decimal_dist  M_sum  M_na  \
# TransactionDT_to_datetime
# 2017-12-01 00:00:00                      0                 NaN      0     3
# 2017-12-01 00:00:01                      0                 NaN      0     6
# 2017-12-01 00:01:09                      0                 NaN      0     0
# 2017-12-01 00:01:39                      0                 NaN      0     6
# 2017-12-01 00:01:46                      0                 NaN      0     8
#
#                            notnull_count
# TransactionDT_to_datetime
# 2017-12-01 00:00:00                  199
# 2017-12-01 00:00:01                  203
# 2017-12-01 00:01:09                  222
# 2017-12-01 00:01:39                  206
# 2017-12-01 00:01:46                  295
#
# [5 rows x 707 columns]

# %%
from feature_engineering import kfold_target_encoding, apply_target_encoder

# %%
from sklearn.model_selection import GroupKFold

folds = GroupKFold(n_splits=6)


preds = []

COLS_TO_USE = [
            i for i in train_test_transformed.columns
            if i not in COLUMNS_TO_REMOVE + ['card1', 'subcard_categorical', 'TransactionDT_dayOfMonth']
        ]

print(COLS_TO_USE, len(COLS_TO_USE))


gbms = []

for fold_ind, (train_idx, val_idx) in enumerate(
    folds.split(
        X=train_test_transformed[:train.shape[0]], 
        y=train_test_transformed[:train.shape[0]]['isFraud'], 
        groups=train_test_transformed[:train.shape[0]]['TransactionDT_split'].tolist()
    )
):

    #if fold_ind == 0:
    #    continue

    print('Fold', fold_ind)

    #     pars = {
    #         'num_leaves': 2 ** 7 - 1,
    #         #'min_data_per_group': 100,
    #         'learning_rate': 0.01,
    #         'feature_fraction': 0.7,
    #         'bagging_fraction': 0.7,
    #         'bagging_seed': RANDOM_STATE,
    #         'bagging_freq': 51,
    #         'cat_smooth': 500,
    #         'lambda_l1': 1.0,
    #         'lambda_l2': 3.0,
    #         'max_bin': 100,
    #         'scale_pos_weight': 7.0,
    #         #'max_cat_to_onehot': 10,
    #         'boosting_type': 'gbdt',
    #         'objective': 'binary',
    #         'metric': ['auc'],
    #         'num_threads': -1,
    #         'seed': RANDOM_STATE
    #     }
    
    pars = {'num_leaves': 200,
          'min_child_samples': 40,
          #'min_sum_hessian_in_leaf': 5e-3,
          #'max_bin': 1023,
          #'min_data_in_leaf': 
          #'scale_pos_weight': 2,
          'objective': 'binary',
          'metric': 'auc',
          'max_depth': 13,
          'learning_rate': 0.01,
          "boosting_type": "goss",
          "top_rate": 0.6,
          "other_rate": 0.1,
          "bagging_freq": 0,
          'nthread': -1,
          
          'pos_bagging_fraction': 0.8,
          'neg_bagging_fraction': 0.01,
          "bagging_fraction": 0.5,
          "bagging_seed": 11,
          'reg_alpha': 0.3,
          'reg_lambda': 0.3,
          
          'feature_fraction': 0.9,
          'min_data_per_group': 25,
          'cat_smooth': 500,
          'max_cat_to_onehot': 8,
            'bagging_seed': RANDOM_STATE,
            'seed': RANDOM_STATE
            
          #'categorical_feature': cat_cols
         }

    cat_c = [i for i in CATEGORICAL_FEATURES
        if i in COLS_TO_USE]

    cur_train = train_test_transformed[:train.shape[0]].iloc[train_idx].copy()
    cur_test = train_test_transformed[:train.shape[0]].iloc[val_idx].copy()
    
    TARGET_ENCODE_COLUMNS = ['ProductCD']
    
    for TARGET_ENCODE_COLUMN in TARGET_ENCODE_COLUMNS:
    
        cur_train = kfold_target_encoding(cur_train, [TARGET_ENCODE_COLUMN])
        cur_test = apply_target_encoder(cur_train, cur_test, [TARGET_ENCODE_COLUMN])

        cur_train[f'target_encoded_{TARGET_ENCODE_COLUMN}'] = cur_train[f'target_encoded_{TARGET_ENCODE_COLUMN}'].astype('float32')
        cur_test[f'target_encoded_{TARGET_ENCODE_COLUMN}'] = cur_test[f'target_encoded_{TARGET_ENCODE_COLUMN}'].astype('float32')

    
    TE_COLUMNS = [f'target_encoded_{i}' for i in TARGET_ENCODE_COLUMNS]
    
    #cur_train_positive = cur_train[cur_train.isFraud == 1].copy()
    #cur_train_negative = cur_train[cur_train.isFraud == 0].sample(frac=0.2).copy()
    #cur_train = pd.concat([cur_train_positive, cur_train_negative])
    #cur_train = cur_train.sample(frac=.2)

    # create dataset for lightgbm
    lgb_train = lgb.Dataset(cur_train[COLS_TO_USE + TE_COLUMNS], cur_train['isFraud'])
    lgb_eval = lgb.Dataset(cur_test[COLS_TO_USE + TE_COLUMNS], cur_test['isFraud'], reference=lgb_train)

    gbm = lgb.train(
        pars,
        lgb_train,
        num_boost_round=20000,
        valid_sets=(lgb_train, lgb_eval),
        valid_names=('train', 'valid'),
        early_stopping_rounds=100,
        feature_name=COLS_TO_USE + TE_COLUMNS,
        categorical_feature=cat_c,
        verbose_eval=100
    )

    gbms.append(gbm)

    te = train_test_transformed[train_test_transformed['TransactionDT_split'] > 17].copy()
    
    for TARGET_ENCODE_COLUMN in TARGET_ENCODE_COLUMNS:
        te = apply_target_encoder(pd.concat([cur_train, cur_test]), te, [TARGET_ENCODE_COLUMN])
        te[f'target_encoded_{TARGET_ENCODE_COLUMN}'] = te[f'target_encoded_{TARGET_ENCODE_COLUMN}'].astype('float32')

    
    preds.append(gbm.predict(te[COLS_TO_USE + TE_COLUMNS]))


print(np.array(np.array([i.best_score['valid']['auc'] for i in gbms])).mean())
# Out:
# ['C1', 'C10', 'C11', 'C12', 'C13', 'C14', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8', 'C9', 'D1', 'D10', 'D11', 'D12', 'D13', 'D14', 'D15', 'D2', 'D3', 'D4', 'D5', 'D6', 'D7', 'D8', 'D9', 'DeviceInfo', 'DeviceType', 'M1', 'M2', 'M3', 'M4', 'M5', 'M6', 'M7', 'M8', 'M9', 'P_emaildomain', 'ProductCD', 'R_emaildomain', 'TransactionAmt', 'V1', 'V10', 'V100', 'V101', 'V102', 'V103', 'V104', 'V105', 'V106', 'V107', 'V108', 'V109', 'V11', 'V110', 'V111', 'V112', 'V113', 'V114', 'V115', 'V116', 'V117', 'V118', 'V119', 'V12', 'V120', 'V121', 'V122', 'V123', 'V124', 'V125', 'V126', 'V126_card1_mean', 'V126_diff1', 'V127', 'V127_card1_mean', 'V127_diff1', 'V128', 'V128_card1_mean', 'V128_diff1', 'V129', 'V129_card1_mean', 'V129_diff1', 'V13', 'V130', 'V130_card1_mean', 'V130_diff1', 'V131', 'V131_card1_mean', 'V131_diff1', 'V132', 'V132_card1_mean', 'V132_diff1', 'V133', 'V133_card1_mean', 'V133_diff1', 'V134', 'V134_card1_mean', 'V134_diff1', 'V135', 'V135_card1_mean', 'V135_diff1', 'V136', 'V136_card1_mean', 'V136_diff1', 'V137', 'V137_card1_mean', 'V137_diff1', 'V138', 'V139', 'V14', 'V140', 'V141', 'V142', 'V143', 'V144', 'V145', 'V146', 'V147', 'V148', 'V149', 'V15', 'V150', 'V151', 'V152', 'V153', 'V154', 'V155', 'V156', 'V157', 'V158', 'V159', 'V16', 'V160', 'V161', 'V162', 'V163', 'V164', 'V165', 'V166', 'V167', 'V168', 'V169', 'V17', 'V170', 'V171', 'V172', 'V173', 'V174', 'V175', 'V176', 'V177', 'V178', 'V179', 'V18', 'V180', 'V181', 'V182', 'V183', 'V184', 'V185', 'V186', 'V187', 'V188', 'V189', 'V19', 'V190', 'V191', 'V192', 'V193', 'V194', 'V195', 'V196', 'V197', 'V198', 'V199', 'V2', 'V20', 'V200', 'V201', 'V202', 'V203', 'V204', 'V205', 'V206', 'V207', 'V208', 'V209', 'V21', 'V210', 'V211', 'V212', 'V213', 'V214', 'V215', 'V216', 'V217', 'V218', 'V219', 'V22', 'V220', 'V221', 'V222', 'V223', 'V224', 'V225', 'V226', 'V227', 'V228', 'V229', 'V23', 'V230', 'V231', 'V232', 'V233', 'V234', 'V235', 'V236', 'V237', 'V238', 'V239', 'V24', 'V240', 'V241', 'V242', 'V243', 'V244', 'V245', 'V246', 'V247', 'V248', 'V249', 'V25', 'V250', 'V251', 'V252', 'V253', 'V254', 'V255', 'V256', 'V257', 'V258', 'V259', 'V26', 'V260', 'V261', 'V262', 'V263', 'V264', 'V265', 'V266', 'V267', 'V268', 'V269', 'V27', 'V270', 'V271', 'V272', 'V273', 'V274', 'V275', 'V276', 'V277', 'V278', 'V279', 'V28', 'V280', 'V281', 'V282', 'V283', 'V284', 'V285', 'V286', 'V287', 'V288', 'V289', 'V29', 'V290', 'V291', 'V292', 'V293', 'V294', 'V295', 'V296', 'V297', 'V298', 'V299', 'V3', 'V30', 'V300', 'V301', 'V302', 'V303', 'V304', 'V305', 'V306', 'V307', 'V308', 'V309', 'V31', 'V310', 'V311', 'V312', 'V313', 'V314', 'V315', 'V316', 'V317', 'V318', 'V319', 'V32', 'V320', 'V321', 'V322', 'V323', 'V324', 'V325', 'V326', 'V327', 'V328', 'V329', 'V33', 'V330', 'V331', 'V332', 'V333', 'V334', 'V335', 'V336', 'V337', 'V338', 'V339', 'V34', 'V35', 'V36', 'V37', 'V38', 'V39', 'V4', 'V40', 'V41', 'V42', 'V43', 'V44', 'V45', 'V46', 'V47', 'V48', 'V49', 'V5', 'V50', 'V51', 'V52', 'V53', 'V54', 'V55', 'V56', 'V57', 'V58', 'V59', 'V6', 'V60', 'V61', 'V62', 'V63', 'V64', 'V65', 'V66', 'V67', 'V68', 'V69', 'V7', 'V70', 'V71', 'V72', 'V73', 'V74', 'V75', 'V76', 'V77', 'V78', 'V79', 'V8', 'V80', 'V81', 'V82', 'V83', 'V84', 'V85', 'V86', 'V87', 'V88', 'V89', 'V9', 'V90', 'V91', 'V92', 'V93', 'V94', 'V95', 'V96', 'V97', 'V98', 'V99', 'addr1', 'addr2', 'card2', 'card3', 'card4', 'card5', 'card6', 'dist1', 'dist2', 'id_01', 'id_02', 'id_03', 'id_04', 'id_05', 'id_06', 'id_07', 'id_08', 'id_09', 'id_10', 'id_11', 'id_12', 'id_13', 'id_14', 'id_15', 'id_16', 'id_17', 'id_18', 'id_19', 'id_20', 'id_21', 'id_22', 'id_23', 'id_24', 'id_25', 'id_26', 'id_27', 'id_28', 'id_29', 'id_30', 'id_31', 'id_32', 'id_33', 'id_34', 'id_35', 'id_36', 'id_37', 'id_38', 'subcard_reg_timestamp', 'time_from_prev_transaction_by_card1', 'time_from_prev_transaction_by_card1_ProductCD', 'time_from_prev_transaction_by_card1_ProductCD_addr1', 'time_from_prev_transaction_by_card1_subcard_categorical', 'time_to_next_tra ...
# Fold 0
# /home/ec2-user/miniconda3/envs/FRAUD/lib/python3.7/site-packages/lightgbm/basic.py:1209: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['DeviceInfo', 'DeviceType', 'M1', 'M2', 'M3', 'M4', 'M5', 'M6', 'M7', 'M8', 'M9', 'OS_NAME', 'OS_V0', 'OS_V1', 'OS_V2', 'OS_VERSION_FULL', 'OS_VERSION_MINIMAL', 'OS_V_MAJOR', 'P_emaildomain', 'P_emaildomain_1', 'P_emaildomain_2', 'P_emaildomain_3', 'ProductCD', 'R_emaildomain', 'R_emaildomain_1', 'R_emaildomain_2', 'R_emaildomain_3', 'addr1', 'addr2', 'card2', 'card3', 'card4', 'card5', 'card6', 'cents_categorical', 'device_name', 'dollars', 'id_12', 'id_13', 'id_14', 'id_15', 'id_16', 'id_17', 'id_18', 'id_19', 'id_20', 'id_21', 'id_22', 'id_23', 'id_24', 'id_25', 'id_26', 'id_27', 'id_28', 'id_29', 'id_30', 'id_31', 'id_31_BROWSER_NAME', 'id_32', 'id_33', 'id_34', 'id_35', 'id_36', 'id_37', 'id_38', 'is_holiday']
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /home/ec2-user/miniconda3/envs/FRAUD/lib/python3.7/site-packages/lightgbm/basic.py:762: UserWarning: categorical_feature in param dict is overridden.
#   warnings.warn('categorical_feature in param dict is overridden.')
# Training until validation scores don't improve for 100 rounds.
# [100]	train's auc: 0.948017	valid's auc: 0.885749
# [200]	train's auc: 0.969885	valid's auc: 0.900699
# [300]	train's auc: 0.981252	valid's auc: 0.909178
# [400]	train's auc: 0.987707	valid's auc: 0.91529
# [500]	train's auc: 0.99186	valid's auc: 0.919456
# [600]	train's auc: 0.994643	valid's auc: 0.922842
# [700]	train's auc: 0.996538	valid's auc: 0.925031
# [800]	train's auc: 0.997707	valid's auc: 0.926868
# [900]	train's auc: 0.998457	valid's auc: 0.928357
# [1000]	train's auc: 0.998994	valid's auc: 0.929487
# [1100]	train's auc: 0.999339	valid's auc: 0.930425
# [1200]	train's auc: 0.999589	valid's auc: 0.931134
# [1300]	train's auc: 0.999747	valid's auc: 0.931578
# [1400]	train's auc: 0.999843	valid's auc: 0.93205
# [1500]	train's auc: 0.999906	valid's auc: 0.932486
# [1600]	train's auc: 0.999945	valid's auc: 0.93293
# [1700]	train's auc: 0.99997	valid's auc: 0.933091
# [1800]	train's auc: 0.999984	valid's auc: 0.933291
# Early stopping, best iteration is:
# [1794]	train's auc: 0.999984	valid's auc: 0.933346
# Fold 1
# /home/ec2-user/miniconda3/envs/FRAUD/lib/python3.7/site-packages/lightgbm/basic.py:1209: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['DeviceInfo', 'DeviceType', 'M1', 'M2', 'M3', 'M4', 'M5', 'M6', 'M7', 'M8', 'M9', 'OS_NAME', 'OS_V0', 'OS_V1', 'OS_V2', 'OS_VERSION_FULL', 'OS_VERSION_MINIMAL', 'OS_V_MAJOR', 'P_emaildomain', 'P_emaildomain_1', 'P_emaildomain_2', 'P_emaildomain_3', 'ProductCD', 'R_emaildomain', 'R_emaildomain_1', 'R_emaildomain_2', 'R_emaildomain_3', 'addr1', 'addr2', 'card2', 'card3', 'card4', 'card5', 'card6', 'cents_categorical', 'device_name', 'dollars', 'id_12', 'id_13', 'id_14', 'id_15', 'id_16', 'id_17', 'id_18', 'id_19', 'id_20', 'id_21', 'id_22', 'id_23', 'id_24', 'id_25', 'id_26', 'id_27', 'id_28', 'id_29', 'id_30', 'id_31', 'id_31_BROWSER_NAME', 'id_32', 'id_33', 'id_34', 'id_35', 'id_36', 'id_37', 'id_38', 'is_holiday']
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /home/ec2-user/miniconda3/envs/FRAUD/lib/python3.7/site-packages/lightgbm/basic.py:762: UserWarning: categorical_feature in param dict is overridden.
#   warnings.warn('categorical_feature in param dict is overridden.')
# Training until validation scores don't improve for 100 rounds.
# [100]	train's auc: 0.946131	valid's auc: 0.918241
# [200]	train's auc: 0.967907	valid's auc: 0.933498
# [300]	train's auc: 0.979434	valid's auc: 0.942154
# [400]	train's auc: 0.987	valid's auc: 0.946542
# [500]	train's auc: 0.991588	valid's auc: 0.949066
# [600]	train's auc: 0.994504	valid's auc: 0.950708
# [700]	train's auc: 0.996402	valid's auc: 0.951992
# [800]	train's auc: 0.997585	valid's auc: 0.952875
# [900]	train's auc: 0.99836	valid's auc: 0.953592
# [1000]	train's auc: 0.998907	valid's auc: 0.954109
# [1100]	train's auc: 0.999294	valid's auc: 0.954504
# [1200]	train's auc: 0.999536	valid's auc: 0.954747
# [1300]	train's auc: 0.999698	valid's auc: 0.955124
# [1400]	train's auc: 0.99981	valid's auc: 0.955248
# [1500]	train's auc: 0.999884	valid's auc: 0.955347
# [1600]	train's auc: 0.999932	valid's auc: 0.955424
# [1700]	train's auc: 0.999958	valid's auc: 0.955536
# [1800]	train's auc: 0.999977	valid's auc: 0.955725
# [1900]	train's auc: 0.999987	valid's auc: 0.955725
# [2000]	train's auc: 0.999993	valid's auc: 0.955765
# [2100]	train's auc: 0.999997	valid's auc: 0.955802
# [2200]	train's auc: 0.999999	valid's auc: 0.955786
# Early stopping, best iteration is:
# [2108]	train's auc: 0.999997	valid's auc: 0.955816
# [200]	train's auc: 0.965979	valid's auc: 0.93517
# [300]	train's auc: 0.9781	valid's auc: 0.943879
# [400]	train's auc: 0.985826	valid's auc: 0.948875
# [500]	train's auc: 0.990446	valid's auc: 0.951387
# [600]	train's auc: 0.993561	valid's auc: 0.952965
# [700]	train's auc: 0.995666	valid's auc: 0.954275
# [800]	train's auc: 0.997132	valid's auc: 0.955692
# [900]	train's auc: 0.998077	valid's auc: 0.956673
# [1000]	train's auc: 0.998754	valid's auc: 0.957633
# [1100]	train's auc: 0.999151	valid's auc: 0.958538
# [1200]	train's auc: 0.999471	valid's auc: 0.958979
# [1300]	train's auc: 0.999652	valid's auc: 0.959357
# [1400]	train's auc: 0.999782	valid's auc: 0.959628
# [1500]	train's auc: 0.999875	valid's auc: 0.959989
# [1600]	train's auc: 0.999923	valid's auc: 0.960214
# [1700]	train's auc: 0.999957	valid's auc: 0.960475
# [1800]	train's auc: 0.999975	valid's auc: 0.960712
# [1900]	train's auc: 0.999986	valid's auc: 0.960873
# [2000]	train's auc: 0.999993	valid's auc: 0.961047
# [2100]	train's auc: 0.999997	valid's auc: 0.961367
# [2200]	train's auc: 0.999999	valid's auc: 0.961523
# [2300]	train's auc: 0.999999	valid's auc: 0.961665
# [2400]	train's auc: 1	valid's auc: 0.961826
# [2500]	train's auc: 1	valid's auc: 0.961834
# [2600]	train's auc: 1	valid's auc: 0.961967
# [2700]	train's auc: 1	valid's auc: 0.962013
# [2800]	train's auc: 1	valid's auc: 0.962145
# [2900]	train's auc: 1	valid's auc: 0.962198
# Early stopping, best iteration is:
# [2808]	train's auc: 1	valid's auc: 0.96216
# Fold 3
# /home/ec2-user/miniconda3/envs/FRAUD/lib/python3.7/site-packages/lightgbm/basic.py:1209: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['DeviceInfo', 'DeviceType', 'M1', 'M2', 'M3', 'M4', 'M5', 'M6', 'M7', 'M8', 'M9', 'OS_NAME', 'OS_V0', 'OS_V1', 'OS_V2', 'OS_VERSION_FULL', 'OS_VERSION_MINIMAL', 'OS_V_MAJOR', 'P_emaildomain', 'P_emaildomain_1', 'P_emaildomain_2', 'P_emaildomain_3', 'ProductCD', 'R_emaildomain', 'R_emaildomain_1', 'R_emaildomain_2', 'R_emaildomain_3', 'addr1', 'addr2', 'card2', 'card3', 'card4', 'card5', 'card6', 'cents_categorical', 'device_name', 'dollars', 'id_12', 'id_13', 'id_14', 'id_15', 'id_16', 'id_17', 'id_18', 'id_19', 'id_20', 'id_21', 'id_22', 'id_23', 'id_24', 'id_25', 'id_26', 'id_27', 'id_28', 'id_29', 'id_30', 'id_31', 'id_31_BROWSER_NAME', 'id_32', 'id_33', 'id_34', 'id_35', 'id_36', 'id_37', 'id_38', 'is_holiday']
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /home/ec2-user/miniconda3/envs/FRAUD/lib/python3.7/site-packages/lightgbm/basic.py:762: UserWarning: categorical_feature in param dict is overridden.
#   warnings.warn('categorical_feature in param dict is overridden.')
# Training until validation scores don't improve for 100 rounds.
# [100]	train's auc: 0.94629	valid's auc: 0.903821
# [200]	train's auc: 0.96787	valid's auc: 0.921562
# [300]	train's auc: 0.979459	valid's auc: 0.929732
# [400]	train's auc: 0.986339	valid's auc: 0.93541
# [500]	train's auc: 0.990849	valid's auc: 0.938673
# [600]	train's auc: 0.993911	valid's auc: 0.940968
# [700]	train's auc: 0.995851	valid's auc: 0.942716
# [800]	train's auc: 0.997269	valid's auc: 0.944151
# [900]	train's auc: 0.99814	valid's auc: 0.945358
# [1000]	train's auc: 0.998729	valid's auc: 0.946079
# [1100]	train's auc: 0.999164	valid's auc: 0.946683
# [1200]	train's auc: 0.999438	valid's auc: 0.946969
# [1300]	train's auc: 0.999631	valid's auc: 0.947051
# [1400]	train's auc: 0.999764	valid's auc: 0.947324
# [1500]	train's auc: 0.999844	valid's auc: 0.947658
# [1600]	train's auc: 0.999901	valid's auc: 0.947836
# [1700]	train's auc: 0.999944	valid's auc: 0.948037
# Early stopping, best iteration is:
# [1680]	train's auc: 0.999938	valid's auc: 0.948076
# Fold 4
# /home/ec2-user/miniconda3/envs/FRAUD/lib/python3.7/site-packages/lightgbm/basic.py:1209: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['DeviceInfo', 'DeviceType', 'M1', 'M2', 'M3', 'M4', 'M5', 'M6', 'M7', 'M8', 'M9', 'OS_NAME', 'OS_V0', 'OS_V1', 'OS_V2', 'OS_VERSION_FULL', 'OS_VERSION_MINIMAL', 'OS_V_MAJOR', 'P_emaildomain', 'P_emaildomain_1', 'P_emaildomain_2', 'P_emaildomain_3', 'ProductCD', 'R_emaildomain', 'R_emaildomain_1', 'R_emaildomain_2', 'R_emaildomain_3', 'addr1', 'addr2', 'card2', 'card3', 'card4', 'card5', 'card6', 'cents_categorical', 'device_name', 'dollars', 'id_12', 'id_13', 'id_14', 'id_15', 'id_16', 'id_17', 'id_18', 'id_19', 'id_20', 'id_21', 'id_22', 'id_23', 'id_24', 'id_25', 'id_26', 'id_27', 'id_28', 'id_29', 'id_30', 'id_31', 'id_31_BROWSER_NAME', 'id_32', 'id_33', 'id_34', 'id_35', 'id_36', 'id_37', 'id_38', 'is_holiday']
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /home/ec2-user/miniconda3/envs/FRAUD/lib/python3.7/site-packages/lightgbm/basic.py:762: UserWarning: categorical_feature in param dict is overridden.
#   warnings.warn('categorical_feature in param dict is overridden.')
# Training until validation scores don't improve for 100 rounds.
# [100]	train's auc: 0.943335	valid's auc: 0.926847
# [200]	train's auc: 0.966809	valid's auc: 0.943873
# [300]	train's auc: 0.97833	valid's auc: 0.949896
# [400]	train's auc: 0.985618	valid's auc: 0.953497
# [500]	train's auc: 0.990174	valid's auc: 0.955676
# [600]	train's auc: 0.993268	valid's auc: 0.956871
# [700]	train's auc: 0.995527	valid's auc: 0.957716
# [800]	train's auc: 0.996932	valid's auc: 0.958253
# [900]	train's auc: 0.997834	valid's auc: 0.958805
# [1000]	train's auc: 0.998569	valid's auc: 0.959372
# [1100]	train's auc: 0.999072	valid's auc: 0.959658
# [1200]	train's auc: 0.999394	valid's auc: 0.959863
# [1300]	train's auc: 0.999617	valid's auc: 0.960029
# [1400]	train's auc: 0.999752	valid's auc: 0.960142
# [1500]	train's auc: 0.999847	valid's auc: 0.960265
# [1600]	train's auc: 0.999909	valid's auc: 0.96032
# [1700]	train's auc: 0.999948	valid's auc: 0.960417
# [1800]	train's auc: 0.999969	valid's auc: 0.960376
# Early stopping, best iteration is:
# [1745]	train's auc: 0.999959	valid's auc: 0.96044
# Fold 5
# /home/ec2-user/miniconda3/envs/FRAUD/lib/python3.7/site-packages/lightgbm/basic.py:1209: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['DeviceInfo', 'DeviceType', 'M1', 'M2', 'M3', 'M4', 'M5', 'M6', 'M7', 'M8', 'M9', 'OS_NAME', 'OS_V0', 'OS_V1', 'OS_V2', 'OS_VERSION_FULL', 'OS_VERSION_MINIMAL', 'OS_V_MAJOR', 'P_emaildomain', 'P_emaildomain_1', 'P_emaildomain_2', 'P_emaildomain_3', 'ProductCD', 'R_emaildomain', 'R_emaildomain_1', 'R_emaildomain_2', 'R_emaildomain_3', 'addr1', 'addr2', 'card2', 'card3', 'card4', 'card5', 'card6', 'cents_categorical', 'device_name', 'dollars', 'id_12', 'id_13', 'id_14', 'id_15', 'id_16', 'id_17', 'id_18', 'id_19', 'id_20', 'id_21', 'id_22', 'id_23', 'id_24', 'id_25', 'id_26', 'id_27', 'id_28', 'id_29', 'id_30', 'id_31', 'id_31_BROWSER_NAME', 'id_32', 'id_33', 'id_34', 'id_35', 'id_36', 'id_37', 'id_38', 'is_holiday']
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /home/ec2-user/miniconda3/envs/FRAUD/lib/python3.7/site-packages/lightgbm/basic.py:762: UserWarning: categorical_feature in param dict is overridden.
#   warnings.warn('categorical_feature in param dict is overridden.')
# Training until validation scores don't improve for 100 rounds.
# [100]	train's auc: 0.943995	valid's auc: 0.915517
# [200]	train's auc: 0.966656	valid's auc: 0.936069
# [300]	train's auc: 0.978556	valid's auc: 0.945832
# [400]	train's auc: 0.985504	valid's auc: 0.950294
# [500]	train's auc: 0.990116	valid's auc: 0.953402
# [600]	train's auc: 0.993373	valid's auc: 0.95552
# [700]	train's auc: 0.995545	valid's auc: 0.957322
# [800]	train's auc: 0.996989	valid's auc: 0.958638
# [900]	train's auc: 0.997953	valid's auc: 0.959689
# [1000]	train's auc: 0.998631	valid's auc: 0.960496
# [1100]	train's auc: 0.999119	valid's auc: 0.96109
# [1200]	train's auc: 0.999409	valid's auc: 0.961537
# [1300]	train's auc: 0.99962	valid's auc: 0.962138
# [1400]	train's auc: 0.99975	valid's auc: 0.962505
# [1500]	train's auc: 0.999841	valid's auc: 0.962793
# [1600]	train's auc: 0.999903	valid's auc: 0.963073
# [1700]	train's auc: 0.999941	valid's auc: 0.963316
# [1800]	train's auc: 0.999966	valid's auc: 0.963332
# Early stopping, best iteration is:
# [1764]	train's auc: 0.99996	valid's auc: 0.963395
# 0.9538722371071886

# %%
sample_submission['TransactionID'] = train_test_transformed[train.shape[0]:]['TransactionID'].values
sample_submission['isFraud'] = np.array(preds).mean(axis=0)
sample_submission.head()

vv = np.array([i.best_score['valid']['auc'] for i in gbms]).mean()
filename = f'submit_ts_kfold_{vv}_mean_shuffled.csv'
sample_submission.to_csv(filename, index=None)
print(filename)

# !KAGGLE_USERNAME=merkylove KAGGLE_KEY=d5a91994e09f1cb75e62c8b8b2967594 kaggle competitions submit ieee-fraud-detection -f {filename} -m "auto"
# Out:
# submit_ts_kfold_0.9538722371071886_mean_shuffled.csv
# 100%|██████████████████████████████████████| 14.2M/14.2M [00:00<00:00, 18.4MB/s]
# Successfully submitted to IEEE-CIS Fraud Detection
